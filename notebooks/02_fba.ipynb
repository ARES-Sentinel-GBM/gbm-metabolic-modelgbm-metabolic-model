# %% [markdown]
# # 02 - Flux Balance Analysis (FBA)
# Simulazione dello stato stazionario del Glioblastoma.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))
from src.io import load_model, save_results
from src.fba import run_fba
model = load_model('../model/gbm_model.xml')
solution = run_fba(model)
print(f'Objective Value: {solution.objective_value}')
save_results(solution.fluxes.to_frame(), 'flux_results_02.csv')
