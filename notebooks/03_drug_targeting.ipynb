# %% [markdown]
# # 03 - Drug Targeting & Gene Knockout
# Identificazione di target terapeutici essenziali.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))
from src.io import load_model
from cobra.flux_analysis import single_gene_deletion
model = load_model('../model/gbm_model.xml')
deletion_results = single_gene_deletion(model, model.genes[:10]) # Esempio primi 10
print(deletion_results.head())
